# %% [markdown]
# # Modified Binary Search

# %% [markdown]
# Whenever we are given a sorted array, linked list or matrix, and are asked to find a certain element.

# %% [markdown]
# ![image.png](attachment:image.png)
