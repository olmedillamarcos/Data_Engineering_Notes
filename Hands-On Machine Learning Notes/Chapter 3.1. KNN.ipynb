# %% [markdown]
# # The K-Nearest Neighbors Algorithm

# %% [markdown]
# A super simple way to to classify data

# %% [markdown]
# ### 1) Start with a dataset with known categories, and cluster the data in this example, PCA is used.
#
# <div><img src="attachment:image.png" width="350"></div>

# %% [markdown]
# ### 2) Add a new cell, with unknown category, to the plot
#
# <div><img src="attachment:image.png" width="350"></div>

# %% [markdown]
# ### 3) Classifiy the new cell by lookin at the neares annotated cells (nearest neighbors)

# %% [markdown]
# We check the categoreis of the K closest neighbors
